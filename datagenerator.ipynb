# %%
import pandas as pd

# %%
import random

# %%
import numpy as np

# %%
def long(row):
    long1 = random.random()+(-123)
    return long1

# %%
def lat(row):
    lat1 = random.random()+(37)
    return lat1

# %%
df = pd.DataFrame(np.zeros((1000, 2)),columns=['lat','long'])

# %%
df['lat']=df.lat.apply(lat)

# %%
df['long']=df.lat.apply(long)

# %%
df.to_csv('')
# Out:
#            lat        long
# 0    37.383726 -122.547050
# 1    37.355589 -122.526065
# 2    37.878239 -122.794481
# 3    37.739686 -122.265488
# 4    37.455718 -122.810387
# 5    37.321059 -122.792396
# 6    37.897664 -122.809966
# 7    37.231005 -122.131527
# 8    37.562177 -122.328204
# 9    37.287948 -122.746277
# 10   37.670768 -122.578083
# 11   37.005291 -122.360270
# 12   37.667663 -122.247627
# 13   37.137396 -122.402910
# 14   37.087624 -122.707248
# 15   37.031308 -122.099928
# 16   37.387817 -122.516036
# 17   37.128241 -122.209173
# 18   37.176545 -122.566758
# 19   37.781760 -122.994732
# 20   37.841167 -122.316484
# 21   37.912358 -122.913101
# 22   37.681660 -122.103153
# 23   37.489646 -122.302456
# 24   37.861048 -122.696978
# 25   37.170187 -122.715546
# 26   37.155187 -122.534685
# 27   37.601013 -122.880004
# 28   37.054881 -122.889099
# 29   37.349815 -122.739303
# ..         ...         ...
# 970  37.716170 -122.680702
# 971  37.628793 -122.635165
# 972  37.952649 -122.650290
# 973  37.419456 -122.363109
# 974  37.786067 -122.302817
# 975  37.332138 -122.025872
# 976  37.778803 -122.124826
# 977  37.258042 -122.492361
# 978  37.142033 -122.833738
# 979  37.907572 -122.087955
# 980  37.009496 -122.304971
# 981  37.694638 -122.173749
# 982  37.294411 -122.277732
# 983  37.690248 -122.542258
# 984  37.940236 -122.328146
# 985  37.178703 -122.476051
# 986  37.411014 -122.493712
# 987  37.357264 -122.554608
# 988  37.813791 -122.850344
# 989  37.756981 -122.615220
# 990  37.261871 -122.509051
# 991  37.758491 -122.560276
# 992  37.491898 -122.038837
# 993  37.463552 -122.362273
# 994  37.352410 -122.484297
# 995  37.899198 -122.142116
# 996  37.236278 -122.948110
# 997  37.780515 -122.413708
# 998  37.891313 -122.426654
# 999  37.869255 -122.511637
#
# [1000 rows x 2 columns]
